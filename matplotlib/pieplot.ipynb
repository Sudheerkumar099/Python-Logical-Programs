# %%
# 1&2
import matplotlib.pyplot as plt
import pandas as pd
prog_lang =  ["Java","Python","PHP","JavaScript","C#", "C++"]
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
plt.pie(popularity,autopct="%0.2f", labels = prog_lang)
plt.title("Popularity of programming")
# Out:
# Text(0.5, 1.0, 'Popularity of programming')

# %%
#3
df =  pd.read_csv("matplotlib/medels.csv")
print(df.columns)
plt.pie(df["gold_medal "],autopct = "%0.1f", labels = df["country"])
plt.title("Medals for each Country")
# Out:
# Index(['country', 'gold_medal '], dtype='object')
# Text(0.5, 1.0, 'Medals for each Country')
